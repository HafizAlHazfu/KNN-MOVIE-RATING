# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
movies_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/movies.csv",
                        usecols=['movieId','title'], dtype={'movieId':'int32','title':'str'})

# %%
ratings_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/ratings.csv",
                        usecols=['userId', 'movieId','rating'],
                         dtype={'userId':'int32','movieId':'int32','rating':'float32'})

# %%
movies_df.head()
# Out:
#    movieId                               title
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)

# %%
movies_df.shape
# Out:
# (9742, 2)

# %%
ratings_df.head()
# Out:
#    userId  movieId  rating
# 0       1        1   4.000
# 1       1        3   4.000
# 2       1        6   4.000
# 3       1       47   5.000
# 4       1       50   5.000

# %%
ratings_df.shape
# Out:
# (100836, 3)

# %%
df = pd.merge(ratings_df, movies_df, on = 'movieId')
df
# Out:
#         userId  movieId  rating                             title
# 0            1        1   4.000                  Toy Story (1995)
# 1            5        1   4.000                  Toy Story (1995)
# 2            7        1   4.500                  Toy Story (1995)
# 3           15        1   2.500                  Toy Story (1995)
# 4           17        1   4.500                  Toy Story (1995)
# ...        ...      ...     ...                               ...
# 100831     610   160341   2.500                  Bloodmoon (1997)
# 100832     610   160527   4.500  Sympathy for the Underdog (1971)
# 100833     610   160836   3.000                     Hazard (2005)
# 100834     610   163937   3.500                Blair Witch (2016)
# 100835     610   163981   3.500                         31 (2016)
#
# [100836 rows x 4 columns]

# %%
combine_movie_rating = df.dropna(axis = 0, subset = ['title'])
movie_ratingCount = (combine_movie_rating.
groupby(by = ['title']) ['rating'].
count().
reset_index().
rename(columns = {'rating' : 'totalRatingCount'})
[['title', 'totalRatingCount']]
)
movie_ratingCount
# Out:
#                                           title  totalRatingCount
# 0                                    '71 (2014)                 1
# 1       'Hellboy': The Seeds of Creation (2004)                 1
# 2                        'Round Midnight (1986)                 2
# 3                           'Salem's Lot (2004)                 1
# 4                     'Til There Was You (1997)                 2
# ...                                         ...               ...
# 9714                            eXistenZ (1999)                22
# 9715                                 xXx (2002)                24
# 9716             xXx: State of the Union (2005)                 5
# 9717                      ¡Three Amigos! (1986)                26
# 9718  À nous la liberté (Freedom for Us) (1931)                 1
#
# [9719 rows x 2 columns]

# %%
rating_with_totalRatingCount = combine_movie_rating.merge(movie_ratingCount, left_on = 'title', right_on = 'title', how = 'left')
rating_with_totalRatingCount.head()
# Out:
#    userId  movieId  rating             title  totalRatingCount
# 0       1        1   4.000  Toy Story (1995)               215
# 1       5        1   4.000  Toy Story (1995)               215
# 2       7        1   4.500  Toy Story (1995)               215
# 3      15        1   2.500  Toy Story (1995)               215
# 4      17        1   4.500  Toy Story (1995)               215

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
print(movie_ratingCount['totalRatingCount'].describe())
# Out:
# count   9719.000
# mean      10.375
# std       22.406
# min        1.000
# 25%        1.000
# 50%        3.000
# 75%        9.000
# max      329.000
# Name: totalRatingCount, dtype: float64

# %%
popularity_threshold =37
rating_popular_movie = rating_with_totalRatingCount.query('totalRatingCount >= @popularity_threshold')
rating_popular_movie.head()
# Out:
#    userId  movieId  rating             title  totalRatingCount
# 0       1        1   4.000  Toy Story (1995)               215
# 1       5        1   4.000  Toy Story (1995)               215
# 2       7        1   4.500  Toy Story (1995)               215
# 3      15        1   2.500  Toy Story (1995)               215
# 4      17        1   4.500  Toy Story (1995)               215

# %%
rating_popular_movie.shape
# Out:
# (52189, 5)

# %%
movie_features_df=rating_popular_movie.pivot_table(index='title',columns='userId',values='rating').fillna(0)
movie_features_df.head()
# Out:
# userId                                               1     2     3     4    \
# title
# (500) Days of Summer (2009)                        0.000 0.000 0.000 0.000
# 10 Things I Hate About You (1999)                  0.000 0.000 0.000 0.000
# 101 Dalmatians (1996)                              0.000 0.000 0.000 0.000
# 101 Dalmatians (One Hundred and One Dalmatians)... 0.000 0.000 0.000 0.000
# 12 Angry Men (1957)                                0.000 0.000 0.000 5.000
#
# userId                                               5     6     7     8    \
# title
# (500) Days of Summer (2009)                        0.000 0.000 0.000 0.000
# 10 Things I Hate About You (1999)                  0.000 0.000 0.000 0.000
# 101 Dalmatians (1996)                              0.000 0.000 0.000 0.000
# 101 Dalmatians (One Hundred and One Dalmatians)... 0.000 0.000 0.000 0.000
# 12 Angry Men (1957)                                0.000 0.000 0.000 0.000
#
# userId                                               9     10   ...   601  \
# title                                                           ...
# (500) Days of Summer (2009)                        0.000 0.000  ... 0.000
# 10 Things I Hate About You (1999)                  0.000 0.000  ... 0.000
# 101 Dalmatians (1996)                              0.000 0.000  ... 0.000
# 101 Dalmatians (One Hundred and One Dalmatians)... 0.000 0.000  ... 0.000
# 12 Angry Men (1957)                                0.000 0.000  ... 5.000
#
# userId                                               602   603   604   605  \
# title
# (500) Days of Summer (2009)                        0.000 0.000 0.000 0.000
# 10 Things I Hate About You (1999)                  0.000 3.000 0.000 5.000
# 101 Dalmatians (1996)                              0.000 4.000 0.000 3.000
# 101 Dalmatians (One Hundred and One Dalmatians)... 0.000 0.000 0.000 0.000
# 12 Angry Men (1957)                                0.000 0.000 0.000 0.000
#
# userId                                               606   607   608   609  \
# title
# (500) Days of Summer (2009)                        0.000 0.000 0.000 0.000
# 10 Things I Hate About You (1999)                  0.000 0.000 0.000 0.000
# 101 Dalmatians (1996)                              0.000 0.000 0.000 0.000
# 101 Dalmatians (One Hundred and One Dalmatians)... 0.000 0.000 0.000 0.000
# 12 Angry Men (1957)                                0.000 0.000 0.000 0.000
#
# userId                                               610
# title
# (500) Days of Summer (2009)                        3.500
# 10 Things I Hate About You (1999)                  0.000
# 101 Dalmatians (1996)                              0.000
# 101 Dalmatians (One Hundred and One Dalmatians)... 0.000
# 12 Angry Men (1957)                                0.000
#
# [5 rows x 608 columns]

# %%
from scipy.sparse import csr_matrix

movie_features_df_matrix = csr_matrix(movie_features_df.values)

from sklearn.neighbors import NearestNeighbors

model_knn = NearestNeighbors(metric = 'cosine', algorithm = 'brute')
model_knn.fit(movie_features_df_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
movie_features_df.head()
# Out:
# userId                                               1     2     3     4    \
# title
# (500) Days of Summer (2009)                        0.000 0.000 0.000 0.000
# 10 Things I Hate About You (1999)                  0.000 0.000 0.000 0.000
# 101 Dalmatians (1996)                              0.000 0.000 0.000 0.000
# 101 Dalmatians (One Hundred and One Dalmatians)... 0.000 0.000 0.000 0.000
# 12 Angry Men (1957)                                0.000 0.000 0.000 5.000
#
# userId                                               5     6     7     8    \
# title
# (500) Days of Summer (2009)                        0.000 0.000 0.000 0.000
# 10 Things I Hate About You (1999)                  0.000 0.000 0.000 0.000
# 101 Dalmatians (1996)                              0.000 0.000 0.000 0.000
# 101 Dalmatians (One Hundred and One Dalmatians)... 0.000 0.000 0.000 0.000
# 12 Angry Men (1957)                                0.000 0.000 0.000 0.000
#
# userId                                               9     10   ...   601  \
# title                                                           ...
# (500) Days of Summer (2009)                        0.000 0.000  ... 0.000
# 10 Things I Hate About You (1999)                  0.000 0.000  ... 0.000
# 101 Dalmatians (1996)                              0.000 0.000  ... 0.000
# 101 Dalmatians (One Hundred and One Dalmatians)... 0.000 0.000  ... 0.000
# 12 Angry Men (1957)                                0.000 0.000  ... 5.000
#
# userId                                               602   603   604   605  \
# title
# (500) Days of Summer (2009)                        0.000 0.000 0.000 0.000
# 10 Things I Hate About You (1999)                  0.000 3.000 0.000 5.000
# 101 Dalmatians (1996)                              0.000 4.000 0.000 3.000
# 101 Dalmatians (One Hundred and One Dalmatians)... 0.000 0.000 0.000 0.000
# 12 Angry Men (1957)                                0.000 0.000 0.000 0.000
#
# userId                                               606   607   608   609  \
# title
# (500) Days of Summer (2009)                        0.000 0.000 0.000 0.000
# 10 Things I Hate About You (1999)                  0.000 0.000 0.000 0.000
# 101 Dalmatians (1996)                              0.000 0.000 0.000 0.000
# 101 Dalmatians (One Hundred and One Dalmatians)... 0.000 0.000 0.000 0.000
# 12 Angry Men (1957)                                0.000 0.000 0.000 0.000
#
# userId                                               610
# title
# (500) Days of Summer (2009)                        3.500
# 10 Things I Hate About You (1999)                  0.000
# 101 Dalmatians (1996)                              0.000
# 101 Dalmatians (One Hundred and One Dalmatians)... 0.000
# 12 Angry Men (1957)                                0.000
#
# [5 rows x 608 columns]

# %%
query_index = np.random.choice(movie_features_df.shape[0])
print(query_index)
distances, indices = model_knn.kneighbors(movie_features_df.iloc[query_index,:].values.reshape(1, -1), n_neighbors = 85)
# Out:
# 31

# %%
movie_features_df.head()
# Out:
# userId                                               1     2     3     4    \
# title
# (500) Days of Summer (2009)                        0.000 0.000 0.000 0.000
# 10 Things I Hate About You (1999)                  0.000 0.000 0.000 0.000
# 101 Dalmatians (1996)                              0.000 0.000 0.000 0.000
# 101 Dalmatians (One Hundred and One Dalmatians)... 0.000 0.000 0.000 0.000
# 12 Angry Men (1957)                                0.000 0.000 0.000 5.000
#
# userId                                               5     6     7     8    \
# title
# (500) Days of Summer (2009)                        0.000 0.000 0.000 0.000
# 10 Things I Hate About You (1999)                  0.000 0.000 0.000 0.000
# 101 Dalmatians (1996)                              0.000 0.000 0.000 0.000
# 101 Dalmatians (One Hundred and One Dalmatians)... 0.000 0.000 0.000 0.000
# 12 Angry Men (1957)                                0.000 0.000 0.000 0.000
#
# userId                                               9     10   ...   601  \
# title                                                           ...
# (500) Days of Summer (2009)                        0.000 0.000  ... 0.000
# 10 Things I Hate About You (1999)                  0.000 0.000  ... 0.000
# 101 Dalmatians (1996)                              0.000 0.000  ... 0.000
# 101 Dalmatians (One Hundred and One Dalmatians)... 0.000 0.000  ... 0.000
# 12 Angry Men (1957)                                0.000 0.000  ... 5.000
#
# userId                                               602   603   604   605  \
# title
# (500) Days of Summer (2009)                        0.000 0.000 0.000 0.000
# 10 Things I Hate About You (1999)                  0.000 3.000 0.000 5.000
# 101 Dalmatians (1996)                              0.000 4.000 0.000 3.000
# 101 Dalmatians (One Hundred and One Dalmatians)... 0.000 0.000 0.000 0.000
# 12 Angry Men (1957)                                0.000 0.000 0.000 0.000
#
# userId                                               606   607   608   609  \
# title
# (500) Days of Summer (2009)                        0.000 0.000 0.000 0.000
# 10 Things I Hate About You (1999)                  0.000 0.000 0.000 0.000
# 101 Dalmatians (1996)                              0.000 0.000 0.000 0.000
# 101 Dalmatians (One Hundred and One Dalmatians)... 0.000 0.000 0.000 0.000
# 12 Angry Men (1957)                                0.000 0.000 0.000 0.000
#
# userId                                               610
# title
# (500) Days of Summer (2009)                        3.500
# 10 Things I Hate About You (1999)                  0.000
# 101 Dalmatians (1996)                              0.000
# 101 Dalmatians (One Hundred and One Dalmatians)... 0.000
# 12 Angry Men (1957)                                0.000
#
# [5 rows x 608 columns]

# %%
for i in range(0, len(distances.flatten())):
    if i ==0:
        print('Recomendations for {0}:\n'.format(movie_features_df.index[query_index]))
    else:
        print ('{0}: {1}, with distance of {2}:'.format(i, movie_features_df.index[indices.flatten()[i]], distances.flatten()[i]))
# Out:
# Recomendations for American Beauty (1999):
#
# 1: Fight Club (1999), with distance of 0.37445080280303955:
# 2: Matrix, The (1999), with distance of 0.3867482542991638:
# 3: Sixth Sense, The (1999), with distance of 0.39999252557754517:
# 4: Pulp Fiction (1994), with distance of 0.40671324729919434:
# 5: Reservoir Dogs (1992), with distance of 0.40821367502212524:
# 6: American History X (1998), with distance of 0.4098238945007324:
# 7: Godfather, The (1972), with distance of 0.42498844861984253:
# 8: Clockwork Orange, A (1971), with distance of 0.4263155460357666:
# 9: Being John Malkovich (1999), with distance of 0.4293973445892334:
# 10: Fargo (1996), with distance of 0.4369259476661682:
# 11: Goodfellas (1990), with distance of 0.44079214334487915:
# 12: Memento (2000), with distance of 0.44220036268234253:
# 13: Saving Private Ryan (1998), with distance of 0.4443005919456482:
# 14: Star Wars: Episode IV - A New Hope (1977), with distance of 0.45213258266448975:
# 15: Silence of the Lambs, The (1991), with distance of 0.45575469732284546:
# 16: Star Wars: Episode V - The Empire Strikes Back (1980), with distance of 0.45793503522872925:
# 17: Ferris Bueller's Day Off (1986), with distance of 0.4673770070075989:
# 18: One Flew Over the Cuckoo's Nest (1975), with distance of 0.4689679741859436:
# 19: Groundhog Day (1993), with distance of 0.4698525667190552:
# 20: Usual Suspects, The (1995), with distance of 0.4704511761665344:
# 21: Seven (a.k.a. Se7en) (1995), with distance of 0.4749283194541931:
# 22: Godfather: Part II, The (1974), with distance of 0.47571325302124023:
# 23: Alien (1979), with distance of 0.47593533992767334:
# 24: Forrest Gump (1994), with distance of 0.47632789611816406:
# 25: Star Wars: Episode VI - Return of the Jedi (1983), with distance of 0.4769918918609619:
# 26: Eternal Sunshine of the Spotless Mind (2004), with distance of 0.4771474003791809:
# 27: Monty Python and the Holy Grail (1975), with distance of 0.47982335090637207:
# 28: L.A. Confidential (1997), with distance of 0.48396629095077515:
# 29: Terminator, The (1984), with distance of 0.48650234937667847:
# 30: Trainspotting (1996), with distance of 0.48882192373275757:
# 31: Good Will Hunting (1997), with distance of 0.48924630880355835:
# 32: Gladiator (2000), with distance of 0.48983609676361084:
# 33: Office Space (1999), with distance of 0.49034619331359863:
# 34: Shawshank Redemption, The (1994), with distance of 0.4906683564186096:
# 35: Big Lebowski, The (1998), with distance of 0.49507641792297363:
# 36: Back to the Future (1985), with distance of 0.4968365430831909:
# 37: Austin Powers: The Spy Who Shagged Me (1999), with distance of 0.49822574853897095:
# 38: Full Metal Jacket (1987), with distance of 0.5009881258010864:
# 39: Breakfast Club, The (1985), with distance of 0.5025005340576172:
# 40: Kill Bill: Vol. 1 (2003), with distance of 0.50413978099823:
# 41: Men in Black (a.k.a. MIB) (1997), with distance of 0.5048518180847168:
# 42: Truman Show, The (1998), with distance of 0.5059645175933838:
# 43: Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981), with distance of 0.5081122517585754:
# 44: There's Something About Mary (1998), with distance of 0.5099391937255859:
# 45: Ghostbusters (a.k.a. Ghost Busters) (1984), with distance of 0.5129633545875549:
# 46: Snatch (2000), with distance of 0.5133514404296875:
# 47: American Pie (1999), with distance of 0.5138779878616333:
# 48: Requiem for a Dream (2000), with distance of 0.5147114396095276:
# 49: Donnie Darko (2001), with distance of 0.5148130655288696:
# 50: Blade Runner (1982), with distance of 0.5154019594192505:
# 51: Lock, Stock & Two Smoking Barrels (1998), with distance of 0.5160755515098572:
# 52: Shining, The (1980), with distance of 0.5166030526161194:
# 53: Apocalypse Now (1979), with distance of 0.5174649953842163:
# 54: Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001), with distance of 0.5189311504364014:
# 55: Run Lola Run (Lola rennt) (1998), with distance of 0.5199089050292969:
# 56: Aliens (1986), with distance of 0.5199393033981323:
# 57: Sin City (2005), with distance of 0.5203433036804199:
# 58: Shrek (2001), with distance of 0.5217628479003906:
# 59: Traffic (2000), with distance of 0.5244295597076416:
# 60: Indiana Jones and the Last Crusade (1989), with distance of 0.5276530981063843:
# 61: Princess Bride, The (1987), with distance of 0.5280618071556091:
# 62: Green Mile, The (1999), with distance of 0.5287526845932007:
# 63: Indiana Jones and the Temple of Doom (1984), with distance of 0.5309440493583679:
# 64: Crouching Tiger, Hidden Dragon (Wo hu cang long) (2000), with distance of 0.5335545539855957:
# 65: Shakespeare in Love (1998), with distance of 0.5347120761871338:
# 66: City of God (Cidade de Deus) (2002), with distance of 0.5364513397216797:
# 67: South Park: Bigger, Longer and Uncut (1999), with distance of 0.5370924472808838:
# 68: Fifth Element, The (1997), with distance of 0.537900447845459:
# 69: Minority Report (2002), with distance of 0.5384426712989807:
# 70: Lord of the Rings: The Fellowship of the Ring, The (2001), with distance of 0.538901686668396:
# 71: Schindler's List (1993), with distance of 0.5394184589385986:
# 72: Austin Powers: International Man of Mystery (1997), with distance of 0.5411794185638428:
# 73: E.T. the Extra-Terrestrial (1982), with distance of 0.5422677993774414:
# 74: Star Wars: Episode I - The Phantom Menace (1999), with distance of 0.5428962707519531:
# 75: Léon: The Professional (a.k.a. The Professional) (Léon) (1994), with distance of 0.5432108044624329:
# 76: Jurassic Park (1993), with distance of 0.5437148809432983:
# 77: High Fidelity (2000), with distance of 0.5458650588989258:
# 78: As Good as It Gets (1997), with distance of 0.5462065935134888:
# 79: Dogma (1999), with distance of 0.5465019345283508:
# 80: Die Hard (1988), with distance of 0.5470284223556519:
# 81: Life Is Beautiful (La Vita è bella) (1997), with distance of 0.5480712652206421:
# 82: Stand by Me (1986), with distance of 0.5483444929122925:
# 83: Beetlejuice (1988), with distance of 0.5486036539077759:
# 84: Terminator 2: Judgment Day (1991), with distance of 0.5486540198326111:
